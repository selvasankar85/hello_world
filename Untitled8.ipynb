# %% [markdown]
# <a href="https://colab.research.google.com/github/selvasankar85/hello_world/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import

# %%
import pandas as pd
data={'Name':['Arun','Bala','Cathy','David'],'Age':[23,28,25,30],'Salary':[30000,40000,35000,45000]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0   Arun   23   30000
# 1   Bala   28   40000
# 2  Cathy   25   35000
# 3  David   30   45000

# %%
print(df['Age'])
# Out:
# 0    23
# 1    28
# 2    25
# 3    30
# Name: Age, dtype: int64

# %%
print(df[['Age']])
# Out:
#    Age
# 0   23
# 1   28
# 2   25
# 3   30

# %%
selcomlumns=df[['Name','Salary']]
print(selcomlumns)
# Out:
#     Name  Salary
# 0   Arun   30000
# 1   Bala   40000
# 2  Cathy   35000
# 3  David   45000

# %%
firstrow=df.iloc[0]
print(firstrow)
# Out:
# Name       Arun
# Age          23
# Salary    30000
# Name: 0, dtype: object

# %%
print(df.iloc[[0]])
# Out:
#    Name  Age  Salary
# 0  Arun   23   30000

# %%
print(df.head(3))
# Out:
#     Name  Age  Salary
# 0   Arun   23   30000
# 1   Bala   28   40000
# 2  Cathy   25   35000

# %%
csalary=df.iloc[2,2]
print(csalary)
# Out:
# 35000

# %%
sdata=df[['Age','Salary']]
print(sdata)
# Out:
#    Age  Salary
# 0   23   30000
# 1   28   40000
# 2   25   35000
# 3   30   45000

# %%
df['Tax']=df['Salary']*0.05
print(df)
# Out:
#     Name  Age  Salary     Tax
# 0   Arun   23   30000  1500.0
# 1   Bala   28   40000  2000.0
# 2  Cathy   25   35000  1750.0
# 3  David   30   45000  2250.0

# %%
dfnew=df.drop('Age',axis=1)
print(dfnew)
