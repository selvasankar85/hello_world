# %%
num=int(input("enter any number"))
if (num>0):
  print("Given number is positive number")
# Out:
# enter any number76
# Given number is positive number

# %%
age=23
if (age>17):
  print("you are eligible to vote")
# Out:
# you are eligible to vote

# %%
num=int(input("enter any number"))
if (num%2==0):
  print("given number is even")
else:
  print("given number is odd")
# Out:
# enter any number64
# given number is even

# %%
ta=76
en=24
ma=75
if(ta>34 and en>34 and ma>34):
  print("you are pass")
else:
  print("you are fail")
# Out:
# you are fail

# %%
phy=87
che=90
com=95
avg=((phy+che+com)/3)
if(avg>80):
  print("A grade")
elif(avg>70):
  print("B grade")
else:
  print("C grade")
# Out:
# A grade

# %%
username=str(input("enter your user name"))
password=str(input("enter your password"))
if(username=="kumari" and password=="hello"):
  print("you are a correct user")
else:
  print("wrong")
# Out:
# enter your user namekumari
# enter your passwordhello
# you are a correct user

# %%
pgm=["c","c++","java","python"]
print("The first element of the list",pgm[0])
print("The last element of the list",pgm[-1])
print("The second element of the list",pgm[1])
pgm[0]="Html"
print("The updated list",pgm)
# Out:
# The first element of the list c
# The last element of the list python
# The second element of the list c++
# The updated list ['Html', 'c++', 'java', 'python']

# %%
marks=[90,67,87,45,78]
print("The mark details",marks)
# Out:
# The mark details [90, 67, 87, 45, 78]

# %%
shoppinglist=["rice","bread","milk","sugar","viva"]
print("Total number of items in a list",len(shoppinglist))
# Out:
# Total number of items in a list 5

# %%
days=["mon","tue","wed","thu","fri","sat","sun"]
for days in days:
 print(days)
# Out:
# mon
# tue
# wed
# thu
# fri
# sat
# sun

# %%
regno=(1245,1246,1247,1248,1249)
print(regno[0])
# Out:
# 1245

# %%
studentdetail={"name":"madhu","age":15,"course":"cs"}
print("studentdetails")
print("Name:",studentdetail["name"])
print("Age:",studentdetail["age"])
print("course:",studentdetail["course"])
print(studentdetail.keys())
# Out:
# studentdetails
# Name: madhu
# Age: 15
# course: cs
# dict_keys(['name', 'age', 'course'])

# %%
rollnum=[12345,12346,12347,12345,12347,12348]
curnum=list(set(rollnum))
print("given list",rollnum)
print("unique list",curnum)
# Out:
# given list [12345, 12346, 12347, 12345, 12347, 12348]
# unique list [12345, 12346, 12347, 12348]
